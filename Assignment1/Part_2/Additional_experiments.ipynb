# %% [markdown]
# # Additional Experiments
#
# Here is the code used to generated some figures in the report, so I do not leave detailed explanations here.

# %%
# Last two figures in the report.
from train_mlp_numpy import train
train('5,5', 0.01, 1000, 10)
train('5,5', 0.01, 1000, 10, 16)
# Out:
# Step: 0, Train Loss: 0.6931, Test Loss: 0.6931, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 10, Train Loss: 0.6931, Test Loss: 0.6931, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 20, Train Loss: 0.6931, Test Loss: 0.6931, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 30, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 40, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 50, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 60, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 70, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 80, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# Step: 90, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.12%, Test Accuracy: 49.50%
# ...
