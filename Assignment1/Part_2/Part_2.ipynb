# %% [markdown]
# # Part 2
#
# 12111012 匡亮
#
# # Task 1, 2
#
# See mlp_numpy.py, modules.py. and train_mlp_numpy.py.
#
# # Task 3

# %%
from train_mlp_numpy import train
train('20', 0.01, 1500, 10)  # Default setting
# Out:
# Step: 0, Train Loss: 0.6932, Test Loss: 0.6932, Train Accuracy: 21.62%, Test Accuracy: 47.00%
# Step: 10, Train Loss: 0.6932, Test Loss: 0.6932, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 20, Train Loss: 0.6931, Test Loss: 0.6932, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 30, Train Loss: 0.6931, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 40, Train Loss: 0.6931, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 50, Train Loss: 0.6930, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 60, Train Loss: 0.6930, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 70, Train Loss: 0.6930, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 80, Train Loss: 0.6930, Test Loss: 0.6933, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# Step: 90, Train Loss: 0.6929, Test Loss: 0.6934, Train Accuracy: 50.75%, Test Accuracy: 47.00%
# ...
