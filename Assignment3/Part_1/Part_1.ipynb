# %% [markdown]
# # Part 1
#
# ## Task 1
#
# See the `.py` files in folder `/Part_1`.
#
# ## Task 2

# %%
from argparse import Namespace
import matplotlib.pyplot as plt
from train import main

config = Namespace(
    input_length=2,
    input_dim=1,
    num_classes=10,
    num_hidden=128,
    batch_size=128,
    learning_rate=0.001,
    max_epoch=20,
    max_norm=10.0,
    data_size=50000,
    portion_train=0.8
)

x = list(range(3, 25))
y = []

for T in x:
    print(f'Current length: {T}')
    config.input_length = T
    y.append(main(config)[1])  # accuracy

plt.figure(figsize=(8, 5))
plt.plot(x, y, marker='o', color='b', label='Accuracy')
plt.xlabel('Length', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# Current length: 3
# ...
# Setting total_len to the maximum possible length.
# ...
# Epoch [0/20], train_loss=2.301185131072998, train_acc=0.1125, val_loss=2.327984571456909, val_acc=0.0
# Epoch [1/20], train_loss=2.2937731742858887, train_acc=0.1375, val_loss=2.3406739234924316, val_acc=0.0
# Epoch [2/20], train_loss=2.287825584411621, train_acc=0.175, val_loss=2.350740671157837, val_acc=0.0
# Epoch [3/20], train_loss=2.280089855194092, train_acc=0.1875, val_loss=2.358912467956543, val_acc=0.0
# Epoch [4/20], train_loss=2.268505573272705, train_acc=0.175, val_loss=2.3653507232666016, val_acc=0.0
# Epoch [5/20], train_loss=2.252713680267334, train_acc=0.1875, val_loss=2.369318962097168, val_acc=0.0
# Epoch [6/20], train_loss=2.2360150814056396, train_acc=0.2125, val_loss=2.3696744441986084, val_acc=0.0
# Epoch [7/20], train_loss=2.220776081085205, train_acc=0.225, val_loss=2.3687849044799805, val_acc=0.0
# ...

# %% [markdown]
# For comparison, here is my result on Assignment 2 Task 3.
#
# ![Assignment 2 Task 3 Result](A2P3_result.png)
